# %%
	
from ngsildclient import Client, Entity, iso8601

client = Client(hostname="localhost",port=1026)
# Out:
# Connected to Context Broker at localhost:1026 | vendor=Orion-LD | version=post-v1.9.0

# %%
client.types.list()
# Out:
# ['TemperatureSensor', 'videoRecorded']

# %%
g = client.query_generator(type="videoRecorded")
list(g)[-10:]
# Out:
# [{'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_24_49_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_24_49_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_24_49_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_24_27_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_24_27_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_24_27_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_26_09_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_26_09_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_26_09_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_34_58_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_34_58_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_34_58_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_34_36_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_34_36_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_34_36_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_33_07_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_33_07_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_33_07_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera1:2025_05_26-01_35_13_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 1}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_35_13_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_35_13_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera2:2025_05_26-01_47_45_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 2}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_47_45_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_47_45_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera2:2025_05_26-01_44_52_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 2}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_44_52_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_44_52_PM.mp4'}},
#  {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:videoRecorded:camera2:2025_05_26-01_48_02_PM', 'type': 'videoRecorded', 'camera': {'type': 'Property', 'value': 2}, 'dateObserved': {'type': 'Property', 'value': '2025_05_26-01_48_02_PM'}, 'inferred': {'type': 'Property', 'value': False}, 'path': {'type': 'Property', 'value': '2025_05_26-01_48_02_PM.mp4'}}]

# %%
def build_entity(sensor: dict) -> Entity:
    e = Entity("TemperatureSensor", f"{sensor['id']}")
    e.obs()
    e.prop("temperature", sensor["temperature"])
    return e

# %%
tempSensor = {"id": "001", "temperature": 17}
entity = build_entity(tempSensor)
print (entity)
#upser entity in client
client.upsert(entity)
# Out:
# {'@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'id': 'urn:ngsi-ld:TemperatureSensor:001', 'type': 'TemperatureSensor', 'dateObserved': {'type': 'Property', 'value': {'@type': 'DateTime', '@value': '2025-05-23T19:54:28Z'}}, 'temperature': {'type': 'Property', 'value': 17}}
# {'@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'id': 'urn:ngsi-ld:TemperatureSensor:001', 'type': 'TemperatureSensor', 'dateObserved': {'type': 'Property', 'value': {'@type': 'DateTime', '@value': '2025-05-23T19:54:28Z'}}, 'temperature': {'type': 'Property', 'value': 17}}

# %%
client.get('urn:ngsi-ld:TemperatureSensor:001')
# Out:
# {'@context': 'https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context-v1.8.jsonld', 'id': 'urn:ngsi-ld:TemperatureSensor:001', 'type': 'TemperatureSensor', 'dateObserved': {'type': 'Property', 'value': {'@type': 'DateTime', '@value': '2025-05-23T19:54:28Z'}}, 'temperature': {'type': 'Property', 'value': 17}}
